# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train_data.drop(["Alley", "FireplaceQu", "PoolQC", "Fence", "MiscFeature"], axis = 1, inplace = True)
test_data.drop(["Alley", "FireplaceQu", "PoolQC", "Fence", "MiscFeature"], axis = 1, inplace = True)

# %%
col = list(train_data.columns)
col.remove("SalePrice")
print(col)
# Out:
# ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold',
# ...

# %%
non_cat_features = ['LotFrontage', "LotArea", "YearBuilt", "YearRemodAdd", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2",
                    "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "LowQualFinSF", "GrLivArea", "BsmtFullBath", 
                    "BsmtHalfBath", "FullBath", "HalfBath", "BedroomAbvGr", "KitchenAbvGr", "TotRmsAbvGrd", "Fireplaces", 
                    "GarageYrBlt", "GarageCars", "GarageArea", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", 
                    "ScreenPorch", "PoolArea", "MiscVal", "MoSold", "YrSold"]

# %%
cat_features = col.copy()
# print(cat_features)
for i in non_cat_features:
#     print(i)
    cat_features.remove(i)

# %%
print(cat_features)
# Out:
# ['Id', 'MSSubClass', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
import category_encoders as ce

# %%
target_enc = ce.TargetEncoder(cols = cat_features)
target_enc.fit(train_data[cat_features], train_data["SalePrice"])
# Out:
# TargetEncoder(cols=['Id', 'MSSubClass', 'MSZoning', 'Street', 'LotShape',
#                     'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#                     'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#                     'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle',
#                     'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#                     'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#                     'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#                     'Heating', ...],
#               drop_invariant=False, handle_missing='value',
#               handle_unknown='value', min_samples_leaf=1, return_df=True,
#               smoothing=1.0, verbose=0)

# %%
t1 = train_data.copy()
t1[cat_features] = target_enc.transform(train_data[cat_features])
t1.head()
# Out:
#              Id     MSSubClass       MSZoning  LotFrontage  LotArea  \
# 0  180921.19589  239948.501672  191004.994787         65.0     8450
# 1  180921.19589  185224.811567  191004.994787         80.0     9600
# 2  180921.19589  239948.501672  191004.994787         68.0    11250
# 3  180921.19589  166772.416667  191004.994787         60.0     9550
# 4  180921.19589  239948.501672  191004.994787         84.0    14260
#
#           Street       LotShape    LandContour     Utilities      LotConfig  \
# 0  181130.538514  164754.818378  180183.746758  180950.95682  176938.047529
# 1  181130.538514  164754.818378  180183.746758  180950.95682  177934.574468
# 2  181130.538514  206101.665289  180183.746758  180950.95682  176938.047529
# 3  181130.538514  206101.665289  180183.746758  180950.95682  181623.425856
# 4  181130.538514  206101.665289  180183.746758  180950.95682  177934.574468
#
#    ...  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  \
# ...

# %%
t1.fillna(t1.mean(), inplace = True)

# %%
t2 = test_data.copy()
t2[cat_features] = target_enc.transform(t2[cat_features])
t2.head()
# Out:
#              Id     MSSubClass       MSZoning  LotFrontage  LotArea  \
# 0  180921.19589  185224.811567  131558.390100         80.0    11622
# 1  180921.19589  185224.811567  191004.994787         81.0    14267
# 2  180921.19589  239948.501672  191004.994787         74.0    13830
# 3  180921.19589  239948.501672  191004.994787         78.0     9978
# 4  180921.19589  200779.080460  191004.994787         43.0     5005
#
#           Street       LotShape    LandContour     Utilities      LotConfig  \
# 0  181130.538514  164754.818378  180183.746758  180950.95682  176938.047529
# 1  181130.538514  206101.665289  180183.746758  180950.95682  181623.425856
# 2  181130.538514  206101.665289  180183.746758  180950.95682  176938.047529
# 3  181130.538514  206101.665289  180183.746758  180950.95682  176938.047529
# 4  181130.538514  206101.665289  231533.940000  180950.95682  176938.047529
#
#    ...  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
t2.fillna(t2.mean(), inplace = True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X_train = t1[col]
Y_train = t1["SalePrice"]

# %%
scaler = StandardScaler()
x = scaler.fit_transform(X_train.copy())

# %%
lr = LinearRegression(normalize = True).fit(x, Y_train)

# %%
lr.score(x, Y_train)
# Out:
# 0.8719399438694958

# %%
gbr = GradientBoostingRegressor().fit(x, Y_train)

# %%
gbr.score(x, Y_train)
# Out:
# 0.9683117049017608

# %%
mlp = MLPRegressor(hidden_layer_sizes = [40, 20, 10, 5], learning_rate_init = 0.1).fit(x, Y_train)

# %%
mlp.score(x, Y_train)
# Out:
# 0.9649179454823844

# %%
x_test = scaler.fit_transform(t2.copy())

# %%
pred = gbr.predict(x_test)

# %%
Id = np.array(test_data["Id"], dtype = int)

# %%
print(len(Id))
print(len(pred))
# Out:
# 1459
# 1459

# %%
ans = pd.DataFrame(Id)
ans["SalePrice"] = pred
ans.columns = ["Id", "SalePrice"]
# ans["Id"].apply(lambda x : int(x))
ans.head()
# Out:
#      Id      SalePrice
# 0  1461  129535.023090
# 1  1462  161700.301877
# 2  1463  190908.349193
# 3  1464  190758.393097
# 4  1465  207469.192758

# %%
ans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 2 columns):
# Id           1459 non-null int32
# SalePrice    1459 non-null float64
# dtypes: float64(1), int32(1)
# memory usage: 17.2 KB

# %%
ans.to_csv("submission.csv", index = False)
